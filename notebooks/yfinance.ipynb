# %%
import yfinance as yf

msft = yf.Ticker("NVDA")
msft.info
# Out:
# {'address1': '2788 San Tomas Expressway',
#  'city': 'Santa Clara',
#  'state': 'CA',
#  'zip': '95051',
#  'country': 'United States',
#  'phone': '408 486 2000',
#  'website': 'https://www.nvidia.com',
#  'industry': 'Semiconductors',
#  'industryKey': 'semiconductors',
#  'industryDisp': 'Semiconductors',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %%
msft.news
# Out:
# [{'uuid': 'ceb4516c-fb9f-3d4f-8287-1960fe4bf78b',
#   'title': 'With Nvidia Up 80% This Year, Are There Any AI Crypto Tokens You Should Be Buying Now?',
#   'publisher': 'Motley Fool',
#   'link': 'https://finance.yahoo.com/m/ceb4516c-fb9f-3d4f-8287-1960fe4bf78b/with-nvidia-up-80%25-this-year%2C.html',
#   'providerPublishTime': 1710027000,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/PY6LSJoKAoILwY25ViLh3g--~B/aD05MzM7dz0xNDAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/ad4acf62a394a1b5a85a15af94b1fa95',
#      'width': 1400,
#      'height': 933,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/yoDVNW7hlQnOzGgfU6N20A--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/ad4acf62a394a1b5a85a15af94b1fa95',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['NVDA']},
# ...

# %%
hist = msft.history(period="1mo")
hist
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-02-09 00:00:00-05:00  705.296954  721.816138  702.087082  721.296204
# 2024-02-12 00:00:00-05:00  725.965960  746.075003  712.466593  722.446106
# 2024-02-13 00:00:00-05:00  703.966997  734.465567  696.167374  721.246216
# 2024-02-14 00:00:00-05:00  731.985679  742.325160  719.346257  738.965332
# 2024-02-15 00:00:00-05:00  738.655377  739.715325  723.966063  726.545959
# 2024-02-16 00:00:00-05:00  740.965245  743.985123  724.976005  726.095947
# 2024-02-20 00:00:00-05:00  719.436207  719.526230  677.308240  694.487427
# 2024-02-21 00:00:00-05:00  680.028070  688.847663  662.448878  674.688293
# 2024-02-22 00:00:00-05:00  750.214784  785.713117  742.165174  785.343140
# 2024-02-23 00:00:00-05:00  807.862111  823.901337  775.663610  788.132996
# 2024-02-26 00:00:00-05:00  796.962605  806.422183  785.013154  790.882874
# 2024-02-27 00:00:00-05:00  793.772752  794.762696  771.583791  786.973083
# ...

# %%
msft.actions
# Out:
#                            Dividends  Stock Splits
# Date
# 2024-03-05 00:00:00-05:00       0.04           0.0

# %%
msft.quarterly_balance_sheet
# Out:
#                                                      2024-01-31  \
# Treasury Shares Number                                      NaN
# Ordinary Shares Number                             2464000000.0
# Share Issued                                       2464000000.0
# Net Debt                                           2429000000.0
# Total Debt                                        11056000000.0
# ...                                                         ...
# Receivables                                        9999000000.0
# Accounts Receivable                                9999000000.0
# Cash Cash Equivalents And Short Term Investments  25984000000.0
# Other Short Term Investments                      18704000000.0
# Cash And Cash Equivalents                          7280000000.0
#
#                                                      2023-10-31  \
# Treasury Shares Number                                      0.0
# Ordinary Shares Number                             2466000000.0
# ...

# %%
msft.calendar
# Out:
# {'Dividend Date': datetime.date(2024, 3, 27),
#  'Ex-Dividend Date': datetime.date(2024, 3, 5),
#  'Earnings Date': [datetime.date(2024, 5, 22), datetime.date(2024, 5, 27)],
#  'Earnings High': 6.12,
#  'Earnings Low': 5.32,
#  'Earnings Average': 5.5,
#  'Revenue High': 26871000000,
#  'Revenue Low': 23660000000,
#  'Revenue Average': 24302600000}

# %%
msft.major_holders
# Out:
# Breakdown                          Value
# insidersPercentHeld              0.03992
# institutionsPercentHeld          0.68020
# institutionsFloatPercentHeld     0.70848
# institutionsCount             5142.00000
